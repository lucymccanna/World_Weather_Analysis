# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Step 3: Create a new set of 2,000 random latitudes and longitudes.

lats = np.random.uniform(low = -90.000, high= 90.000, size =2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the lats and lngs to a list

coordinates = list(lat_lngs)

# %%
# Step 4: Get the nearest city using the citipy module.

# create list to hold cities
cities = []

#Identify cities for each lats and lngs combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Create an empty list for city data
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Set up counters
record_count = 1
set_count = 1

# Loop through cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each city
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]


        # Append city data into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | topolobampo
# Processing Record 3 of Set 1 | alekseyevsk
# Processing Record 4 of Set 1 | lebu
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | san jose
# Processing Record 7 of Set 1 | ternate
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | alta floresta
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | laguna
# Processing Record 14 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | lompoc
# Processing Record 18 of Set 1 | srednekolymsk
# Processing Record 19 of Set 1 | gat
# Processing Record 20 of Set 1 | coihaique
# Processing Record 21 of Set 1 | kashi
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | viking
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | pangkalanbuun
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | araouane
# Processing Record 31 of Set 1 | shiyan
# Processing Record 32 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | taltal
# Processing Record 36 of Set 1 | egvekinot
# Processing Record 37 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 1 | rocha
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | winnemucca
# Processing Record 41 of Set 1 | lida
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | hasaki
# Processing Record 44 of Set 1 | lakes entrance
# Processing Record 45 of Set 1 | porto novo
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | pachmarhi
# Processing Record 48 of Set 1 | oranjestad
# Processing Record 49 of Set 1 | cherskiy
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | quatre cocos
# Processing Record 2 of Set 2 | ilebo
# Processing Record 3 of Set 2 | imbituba
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | tiksi
# Processing Record 6 of Set 2 | gangotri
# City not found. Skipping...
# Processing Record 7 of Set 2 | katsuura
# Processing Record 8 of Set 2 | san patricio
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | vila velha
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | kahului
# Processing Record 13 of Set 2 | tsiroanomandidy
# Processing Record 14 of Set 2 | itaguai
# Processing Record 15 of Set 2 | mayor pablo lagerenza
# Processing Record 16 of Set 2 | suda
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | dunedin
# Processing Record 22 of Set 2 | pousat
# City not found. Skipping...
# Processing Record 23 of Set 2 | knysna
# Processing Record 24 of Set 2 | ahipara
# Processing Record 25 of Set 2 | vanderhoof
# Processing Record 26 of Set 2 | chuy
# Processing Record 27 of Set 2 | dingle
# Processing Record 28 of Set 2 | peniche
# Processing Record 29 of Set 2 | jalu
# Processing Record 30 of Set 2 | jumla
# Processing Record 31 of Set 2 | pasighat
# Processing Record 32 of Set 2 | belmonte
# Processing Record 33 of Set 2 | maniitsoq
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | cayenne
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | muros
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | clyde river
# Processing Record 41 of Set 2 | carahue
# Processing Record 42 of Set 2 | cidreira
# Processing Record 43 of Set 2 | hilo
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | erenhot
# Processing Record 47 of Set 2 | gilbues
# Processing Record 48 of Set 2 | lavrentiya
# Processing Record 49 of Set 2 | vardo
# Processing Record 50 of Set 2 | hualmay
# Processing Record 1 of Set 3 | bluff
# Processing Record 2 of Set 3 | esperance
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 3 | akyab
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 3 | nuevo ideal
# Processing Record 9 of Set 3 | husavik
# Processing Record 10 of Set 3 | klaksvik
# Processing Record 11 of Set 3 | traismauer
# Processing Record 12 of Set 3 | yumen
# Processing Record 13 of Set 3 | el badari
# City not found. Skipping...
# Processing Record 14 of Set 3 | tuktoyaktuk
# Processing Record 15 of Set 3 | airai
# Processing Record 16 of Set 3 | barrow
# Processing Record 17 of Set 3 | tatarsk
# Processing Record 18 of Set 3 | salinopolis
# Processing Record 19 of Set 3 | broome
# Processing Record 20 of Set 3 | omsukchan
# Processing Record 21 of Set 3 | catuday
# Processing Record 22 of Set 3 | elliot lake
# Processing Record 23 of Set 3 | kualakapuas
# Processing Record 24 of Set 3 | lazo
# Processing Record 25 of Set 3 | victoria
# Processing Record 26 of Set 3 | araguaina
# Processing Record 27 of Set 3 | faanui
# Processing Record 28 of Set 3 | dikson
# Processing Record 29 of Set 3 | thayetmyo
# Processing Record 30 of Set 3 | barcelona
# Processing Record 31 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 3 | kuva
# City not found. Skipping...
# Processing Record 33 of Set 3 | letlhakane
# Processing Record 34 of Set 3 | pedasi
# Processing Record 35 of Set 3 | charters towers
# Processing Record 36 of Set 3 | banjar
# Processing Record 37 of Set 3 | belaya gora
# Processing Record 38 of Set 3 | cap malheureux
# Processing Record 39 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 3 | boysun
# Processing Record 41 of Set 3 | tuatapere
# Processing Record 42 of Set 3 | mehran
# Processing Record 43 of Set 3 | omboue
# Processing Record 44 of Set 3 | lagoa
# Processing Record 45 of Set 3 | chokurdakh
# Processing Record 46 of Set 3 | saint-georges
# Processing Record 47 of Set 3 | sakaiminato
# Processing Record 48 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 50 of Set 3 | sao jose da coroa grande
# Processing Record 1 of Set 4 | dhamrai
# Processing Record 2 of Set 4 | nikolskoye
# Processing Record 3 of Set 4 | lensk
# Processing Record 4 of Set 4 | hithadhoo
# Processing Record 5 of Set 4 | carnarvon
# Processing Record 6 of Set 4 | severo-kurilsk
# Processing Record 7 of Set 4 | mahebourg
# Processing Record 8 of Set 4 | pangoa
# Processing Record 9 of Set 4 | kaeo
# Processing Record 10 of Set 4 | geghamasar
# Processing Record 11 of Set 4 | camacari
# Processing Record 12 of Set 4 | zilair
# Processing Record 13 of Set 4 | upington
# Processing Record 14 of Set 4 | karoi
# Processing Record 15 of Set 4 | denpasar
# Processing Record 16 of Set 4 | lafiagi
# Processing Record 17 of Set 4 | port blair
# Processing Record 18 of Set 4 | jiazi
# Processing Record 19 of Set 4 | gayny
# Processing Record 20 of Set 4 | lebedinyy
# Processing Record 21 of Set 4 | sawakin
# Processing Record 22 of Set 4 | college
# Processing Record 23 of Set 4 | azare
# Processing Record 24 of Set 4 | kjollefjord
# Processing Record 25 of Set 4 | ponta do sol
# Processing Record 26 of Set 4 | saint george
# Processing Record 27 of Set 4 | marquette
# Processing Record 28 of Set 4 | ahumada
# City not found. Skipping...
# Processing Record 29 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 4 | paamiut
# Processing Record 31 of Set 4 | sao joao da barra
# Processing Record 32 of Set 4 | toora-khem
# Processing Record 33 of Set 4 | matara
# Processing Record 34 of Set 4 | sharlyk
# Processing Record 35 of Set 4 | yanam
# Processing Record 36 of Set 4 | longyearbyen
# Processing Record 37 of Set 4 | aurich
# Processing Record 38 of Set 4 | padang
# Processing Record 39 of Set 4 | upernavik
# Processing Record 40 of Set 4 | opuwo
# Processing Record 41 of Set 4 | katobu
# Processing Record 42 of Set 4 | la asuncion
# Processing Record 43 of Set 4 | saint anthony
# Processing Record 44 of Set 4 | buchanan
# Processing Record 45 of Set 4 | minbu
# Processing Record 46 of Set 4 | nizhnevartovsk
# Processing Record 47 of Set 4 | san cristobal
# Processing Record 48 of Set 4 | te anau
# Processing Record 49 of Set 4 | rafaela
# Processing Record 50 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 1 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 5 | aberdeen
# Processing Record 3 of Set 5 | los llanos de aridane
# Processing Record 4 of Set 5 | conceicao da barra
# Processing Record 5 of Set 5 | codrington
# Processing Record 6 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 5 | kasongo-lunda
# Processing Record 8 of Set 5 | hebi
# Processing Record 9 of Set 5 | fairbanks
# Processing Record 10 of Set 5 | praia da vitoria
# Processing Record 11 of Set 5 | castro
# Processing Record 12 of Set 5 | haines junction
# Processing Record 13 of Set 5 | ilulissat
# Processing Record 14 of Set 5 | christchurch
# Processing Record 15 of Set 5 | anloga
# Processing Record 16 of Set 5 | pevek
# Processing Record 17 of Set 5 | mao
# Processing Record 18 of Set 5 | manakara
# Processing Record 19 of Set 5 | kilindoni
# Processing Record 20 of Set 5 | gwadar
# Processing Record 21 of Set 5 | kavieng
# Processing Record 22 of Set 5 | maarianhamina
# Processing Record 23 of Set 5 | kaduqli
# Processing Record 24 of Set 5 | khatanga
# Processing Record 25 of Set 5 | changji
# Processing Record 26 of Set 5 | muisne
# Processing Record 27 of Set 5 | iralaya
# Processing Record 28 of Set 5 | iquitos
# Processing Record 29 of Set 5 | liuli
# Processing Record 30 of Set 5 | makokou
# Processing Record 31 of Set 5 | tura
# Processing Record 32 of Set 5 | evensk
# Processing Record 33 of Set 5 | marovoay
# Processing Record 34 of Set 5 | misratah
# Processing Record 35 of Set 5 | mongomo
# Processing Record 36 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 5 | ouadda
# Processing Record 38 of Set 5 | massakory
# Processing Record 39 of Set 5 | namtsy
# Processing Record 40 of Set 5 | tchaourou
# Processing Record 41 of Set 5 | alice springs
# Processing Record 42 of Set 5 | vallenar
# Processing Record 43 of Set 5 | thaton
# Processing Record 44 of Set 5 | okato
# Processing Record 45 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 47 of Set 5 | ovalle
# Processing Record 48 of Set 5 | rawson
# Processing Record 49 of Set 5 | olafsvik
# Processing Record 50 of Set 5 | aosta
# Processing Record 1 of Set 6 | lengnau
# Processing Record 2 of Set 6 | homer
# Processing Record 3 of Set 6 | lorengau
# Processing Record 4 of Set 6 | drayton valley
# Processing Record 5 of Set 6 | nybro
# Processing Record 6 of Set 6 | provideniya
# Processing Record 7 of Set 6 | lapua
# Processing Record 8 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 6 | cabo san lucas
# Processing Record 10 of Set 6 | malakal
# Processing Record 11 of Set 6 | port lincoln
# Processing Record 12 of Set 6 | torbat-e jam
# Processing Record 13 of Set 6 | liverpool
# Processing Record 14 of Set 6 | tiarei
# Processing Record 15 of Set 6 | sao sebastiao
# Processing Record 16 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 6 | tautira
# Processing Record 18 of Set 6 | vila franca do campo
# Processing Record 19 of Set 6 | calvinia
# Processing Record 20 of Set 6 | niquero
# Processing Record 21 of Set 6 | cuamba
# Processing Record 22 of Set 6 | santiago del estero
# Processing Record 23 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 25 of Set 6 | luderitz
# Processing Record 26 of Set 6 | kochi
# Processing Record 27 of Set 6 | mar del plata
# Processing Record 28 of Set 6 | coahuayana
# Processing Record 29 of Set 6 | la trinite
# Processing Record 30 of Set 6 | tadine
# Processing Record 31 of Set 6 | palmer
# Processing Record 32 of Set 6 | yabrud
# Processing Record 33 of Set 6 | ixtapa
# Processing Record 34 of Set 6 | saint-leu
# Processing Record 35 of Set 6 | namatanai
# Processing Record 36 of Set 6 | bambous virieux
# Processing Record 37 of Set 6 | redmond
# Processing Record 38 of Set 6 | balikpapan
# Processing Record 39 of Set 6 | marystown
# Processing Record 40 of Set 6 | iqaluit
# Processing Record 41 of Set 6 | vao
# Processing Record 42 of Set 6 | lidice
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | arraial do cabo
# Processing Record 45 of Set 6 | port-cartier
# Processing Record 46 of Set 6 | orange
# Processing Record 47 of Set 6 | chumikan
# Processing Record 48 of Set 6 | lucapa
# Processing Record 49 of Set 6 | soyo
# Processing Record 50 of Set 6 | torbay
# Processing Record 1 of Set 7 | cabedelo
# Processing Record 2 of Set 7 | richards bay
# Processing Record 3 of Set 7 | korla
# Processing Record 4 of Set 7 | jacareacanga
# Processing Record 5 of Set 7 | henties bay
# Processing Record 6 of Set 7 | ostrovnoy
# Processing Record 7 of Set 7 | macia
# Processing Record 8 of Set 7 | coquimbo
# Processing Record 9 of Set 7 | haimen
# Processing Record 10 of Set 7 | sheridan
# Processing Record 11 of Set 7 | nanortalik
# Processing Record 12 of Set 7 | naze
# Processing Record 13 of Set 7 | yar-sale
# Processing Record 14 of Set 7 | sucua
# Processing Record 15 of Set 7 | nyaunglebin
# Processing Record 16 of Set 7 | kirensk
# Processing Record 17 of Set 7 | micheweni
# Processing Record 18 of Set 7 | sovetskiy
# Processing Record 19 of Set 7 | kepno
# Processing Record 20 of Set 7 | killybegs
# Processing Record 21 of Set 7 | sao miguel do araguaia
# Processing Record 22 of Set 7 | batemans bay
# Processing Record 23 of Set 7 | maceio
# Processing Record 24 of Set 7 | ironton
# Processing Record 25 of Set 7 | high level
# Processing Record 26 of Set 7 | tieli
# Processing Record 27 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 7 | le vauclin
# Processing Record 29 of Set 7 | lithakia
# Processing Record 30 of Set 7 | cookshire
# City not found. Skipping...
# Processing Record 31 of Set 7 | kalmunai
# Processing Record 32 of Set 7 | nome
# Processing Record 33 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 7 | norman wells
# Processing Record 35 of Set 7 | ust-kuyga
# Processing Record 36 of Set 7 | serebryansk
# Processing Record 37 of Set 7 | rangapara
# Processing Record 38 of Set 7 | humaita
# Processing Record 39 of Set 7 | fomboni
# Processing Record 40 of Set 7 | aykhal
# Processing Record 41 of Set 7 | ibateguara
# Processing Record 42 of Set 7 | gemena
# Processing Record 43 of Set 7 | narsaq
# Processing Record 44 of Set 7 | san vicente de canete
# Processing Record 45 of Set 7 | farafenni
# Processing Record 46 of Set 7 | tupancireta
# Processing Record 47 of Set 7 | coari
# Processing Record 48 of Set 7 | rawlins
# Processing Record 49 of Set 7 | jinxiang
# Processing Record 50 of Set 7 | saint pete beach
# Processing Record 1 of Set 8 | maksatikha
# Processing Record 2 of Set 8 | kyra
# Processing Record 3 of Set 8 | mahabad
# Processing Record 4 of Set 8 | sorong
# Processing Record 5 of Set 8 | sokolo
# Processing Record 6 of Set 8 | lydenburg
# Processing Record 7 of Set 8 | nouadhibou
# Processing Record 8 of Set 8 | progreso
# Processing Record 9 of Set 8 | mount gambier
# Processing Record 10 of Set 8 | oussouye
# Processing Record 11 of Set 8 | ewa beach
# Processing Record 12 of Set 8 | tual
# Processing Record 13 of Set 8 | ekhabi
# Processing Record 14 of Set 8 | abashiri
# Processing Record 15 of Set 8 | bilma
# Processing Record 16 of Set 8 | varhaug
# Processing Record 17 of Set 8 | staryy nadym
# Processing Record 18 of Set 8 | champerico
# Processing Record 19 of Set 8 | mahajanga
# Processing Record 20 of Set 8 | georgiyevka
# Processing Record 21 of Set 8 | lillehammer
# Processing Record 22 of Set 8 | mirabad
# Processing Record 23 of Set 8 | morros
# Processing Record 24 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 25 of Set 8 | varzea grande
# Processing Record 26 of Set 8 | khromtau
# Processing Record 27 of Set 8 | dawei
# Processing Record 28 of Set 8 | margate
# Processing Record 29 of Set 8 | santa fe
# Processing Record 30 of Set 8 | amazar
# Processing Record 31 of Set 8 | kapurthala
# Processing Record 32 of Set 8 | namwala
# Processing Record 33 of Set 8 | avera
# Processing Record 34 of Set 8 | myre
# Processing Record 35 of Set 8 | neuquen
# Processing Record 36 of Set 8 | rabo de peixe
# Processing Record 37 of Set 8 | fortuna
# Processing Record 38 of Set 8 | davenda
# Processing Record 39 of Set 8 | mapiripan
# Processing Record 40 of Set 8 | holme
# Processing Record 41 of Set 8 | kuching
# Processing Record 42 of Set 8 | yenotayevka
# Processing Record 43 of Set 8 | bourne
# Processing Record 44 of Set 8 | bosaso
# Processing Record 45 of Set 8 | ahuimanu
# Processing Record 46 of Set 8 | beachwood
# Processing Record 47 of Set 8 | puerto escondido
# Processing Record 48 of Set 8 | kousseri
# Processing Record 49 of Set 8 | mooi river
# City not found. Skipping...
# Processing Record 50 of Set 8 | leonidovo
# Processing Record 1 of Set 9 | iquique
# Processing Record 2 of Set 9 | mehamn
# Processing Record 3 of Set 9 | vestmannaeyjar
# Processing Record 4 of Set 9 | hokitika
# Processing Record 5 of Set 9 | gulu
# Processing Record 6 of Set 9 | dakar
# Processing Record 7 of Set 9 | talnakh
# Processing Record 8 of Set 9 | talcahuano
# Processing Record 9 of Set 9 | pacifica
# Processing Record 10 of Set 9 | mahaicony
# City not found. Skipping...
# Processing Record 11 of Set 9 | vitim
# Processing Record 12 of Set 9 | ketchikan
# Processing Record 13 of Set 9 | salalah
# Processing Record 14 of Set 9 | bagdarin
# Processing Record 15 of Set 9 | honiara
# Processing Record 16 of Set 9 | berlevag
# Processing Record 17 of Set 9 | bonthe
# Processing Record 18 of Set 9 | isangel
# Processing Record 19 of Set 9 | aksarka
# Processing Record 20 of Set 9 | saint-augustin
# Processing Record 21 of Set 9 | kuandian
# Processing Record 22 of Set 9 | presidencia roque saenz pena
# Processing Record 23 of Set 9 | praia
# Processing Record 24 of Set 9 | dusetos
# Processing Record 25 of Set 9 | pisco
# Processing Record 26 of Set 9 | worland
# Processing Record 27 of Set 9 | sorkjosen
# Processing Record 28 of Set 9 | turtkul
# City not found. Skipping...
# Processing Record 29 of Set 9 | bengkulu
# Processing Record 30 of Set 9 | zenzeli
# Processing Record 31 of Set 9 | mumford
# Processing Record 32 of Set 9 | cairns
# Processing Record 33 of Set 9 | sinnamary
# Processing Record 34 of Set 9 | kalabo
# Processing Record 35 of Set 9 | yulara
# Processing Record 36 of Set 9 | katastarion
# Processing Record 37 of Set 9 | gunnedah
# Processing Record 38 of Set 9 | mariel
# Processing Record 39 of Set 9 | nizhniy baskunchak
# Processing Record 40 of Set 9 | kapuskasing
# Processing Record 41 of Set 9 | moerai
# Processing Record 42 of Set 9 | fort saint james
# Processing Record 43 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 44 of Set 9 | matelica
# Processing Record 45 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 46 of Set 9 | roanoke
# Processing Record 47 of Set 9 | butembo
# Processing Record 48 of Set 9 | alofi
# Processing Record 49 of Set 9 | ajdabiya
# Processing Record 50 of Set 9 | garachine
# Processing Record 1 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 10 | shurob
# Processing Record 3 of Set 10 | sitka
# Processing Record 4 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 10 | broken hill
# Processing Record 6 of Set 10 | chapais
# Processing Record 7 of Set 10 | itarema
# Processing Record 8 of Set 10 | the valley
# Processing Record 9 of Set 10 | kruisfontein
# Processing Record 10 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 11 of Set 10 | hainburg
# Processing Record 12 of Set 10 | pangai
# Processing Record 13 of Set 10 | najran
# Processing Record 14 of Set 10 | hambantota
# Processing Record 15 of Set 10 | okhansk
# Processing Record 16 of Set 10 | saldanha
# Processing Record 17 of Set 10 | isla vista
# Processing Record 18 of Set 10 | ambilobe
# Processing Record 19 of Set 10 | vostok
# Processing Record 20 of Set 10 | auki
# Processing Record 21 of Set 10 | garowe
# Processing Record 22 of Set 10 | boende
# Processing Record 23 of Set 10 | labuhan
# Processing Record 24 of Set 10 | durban
# Processing Record 25 of Set 10 | qasigiannguit
# Processing Record 26 of Set 10 | kysyl-syr
# Processing Record 27 of Set 10 | ekibastuz
# Processing Record 28 of Set 10 | kupang
# Processing Record 29 of Set 10 | ratnagiri
# Processing Record 30 of Set 10 | tikalaan
# City not found. Skipping...
# Processing Record 31 of Set 10 | sept-iles
# Processing Record 32 of Set 10 | lieksa
# Processing Record 33 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 10 | caravelas
# Processing Record 36 of Set 10 | karratha
# Processing Record 37 of Set 10 | karaton
# Processing Record 38 of Set 10 | marang
# Processing Record 39 of Set 10 | makat
# Processing Record 40 of Set 10 | morgan city
# Processing Record 41 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 42 of Set 10 | ulaanbaatar
# Processing Record 43 of Set 10 | phuket
# Processing Record 44 of Set 10 | ucluelet
# Processing Record 45 of Set 10 | dzheguta
# Processing Record 46 of Set 10 | huarmey
# Processing Record 47 of Set 10 | nara
# Processing Record 48 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 10 | takasaki
# Processing Record 50 of Set 10 | atar
# Processing Record 1 of Set 11 | xuddur
# Processing Record 2 of Set 11 | hamilton
# Processing Record 3 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 4 of Set 11 | torit
# Processing Record 5 of Set 11 | labytnangi
# Processing Record 6 of Set 11 | hami
# Processing Record 7 of Set 11 | hobyo
# Processing Record 8 of Set 11 | saint-francois
# Processing Record 9 of Set 11 | blythe
# Processing Record 10 of Set 11 | shenjiamen
# Processing Record 11 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 12 of Set 11 | aklavik
# Processing Record 13 of Set 11 | dalbandin
# Processing Record 14 of Set 11 | byron bay
# Processing Record 15 of Set 11 | bereda
# Processing Record 16 of Set 11 | arlit
# Processing Record 17 of Set 11 | illapel
# Processing Record 18 of Set 11 | arroyo
# Processing Record 19 of Set 11 | bua yai
# Processing Record 20 of Set 11 | moose factory
# Processing Record 21 of Set 11 | kem
# Processing Record 22 of Set 11 | baykit
# Processing Record 23 of Set 11 | gebze
# Processing Record 24 of Set 11 | port macquarie
# Processing Record 25 of Set 11 | tabuk
# Processing Record 26 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 11 | dzitbalche
# Processing Record 28 of Set 11 | krasnoarmeysk
# Processing Record 29 of Set 11 | ukiah
# Processing Record 30 of Set 11 | ye
# City not found. Skipping...
# Processing Record 31 of Set 11 | filadelfia
# Processing Record 32 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 33 of Set 11 | wakkanai
# Processing Record 34 of Set 11 | jian
# Processing Record 35 of Set 11 | souillac
# Processing Record 36 of Set 11 | honningsvag
# Processing Record 37 of Set 11 | zelenogradsk
# Processing Record 38 of Set 11 | novyy urengoy
# Processing Record 39 of Set 11 | buluang
# Processing Record 40 of Set 11 | visby
# Processing Record 41 of Set 11 | culebra
# Processing Record 42 of Set 11 | altay
# Processing Record 43 of Set 11 | seoul
# Processing Record 44 of Set 11 | barela
# Processing Record 45 of Set 11 | salym
# Processing Record 46 of Set 11 | alghero
# Processing Record 47 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 11 | badarwas
# Processing Record 49 of Set 11 | winslow
# Processing Record 50 of Set 11 | svetlogorsk
# Processing Record 1 of Set 12 | hojai
# Processing Record 2 of Set 12 | victoria point
# Processing Record 3 of Set 12 | tungor
# Processing Record 4 of Set 12 | mogadishu
# Processing Record 5 of Set 12 | aswan
# Processing Record 6 of Set 12 | saint-joseph
# Processing Record 7 of Set 12 | tonk
# Processing Record 8 of Set 12 | ancud
# Processing Record 9 of Set 12 | faya
# Processing Record 10 of Set 12 | deputatskiy
# Processing Record 11 of Set 12 | chara
# Processing Record 12 of Set 12 | cervo
# Processing Record 13 of Set 12 | la rioja
# Processing Record 14 of Set 12 | louis trichardt
# Processing Record 15 of Set 12 | puerto rondon
# Processing Record 16 of Set 12 | wukari
# Processing Record 17 of Set 12 | beringovskiy
# Processing Record 18 of Set 12 | funtua
# Processing Record 19 of Set 12 | burica
# City not found. Skipping...
# Processing Record 20 of Set 12 | avdon
# Processing Record 21 of Set 12 | takoradi
# Processing Record 22 of Set 12 | uzventis
# Processing Record 23 of Set 12 | luocheng
# Processing Record 24 of Set 12 | menongue
# Processing Record 25 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 12 | ferkessedougou
# Processing Record 27 of Set 12 | pacific grove
# Processing Record 28 of Set 12 | rockhampton
# Processing Record 29 of Set 12 | asau
# Processing Record 30 of Set 12 | xining
# Processing Record 31 of Set 12 | san matias
# Processing Record 32 of Set 12 | yerbogachen
# Processing Record 33 of Set 12 | oyama
# Processing Record 34 of Set 12 | boras
# Processing Record 35 of Set 12 | jiwani
# Processing Record 36 of Set 12 | moramanga
# Processing Record 37 of Set 12 | ugoofaaru
# Processing Record 38 of Set 12 | minsk
# Processing Record 39 of Set 12 | nantucket
# Processing Record 40 of Set 12 | oskaloosa
# Processing Record 41 of Set 12 | osa
# Processing Record 42 of Set 12 | ust-nera
# Processing Record 43 of Set 12 | umm lajj
# Processing Record 44 of Set 12 | bathsheba
# Processing Record 45 of Set 12 | paramirim
# Processing Record 46 of Set 12 | batouri
# Processing Record 47 of Set 12 | kytmanovo
# Processing Record 48 of Set 12 | orlik
# Processing Record 49 of Set 12 | dharchula
# Processing Record 50 of Set 12 | nizhniy tsasuchey
# Processing Record 1 of Set 13 | ushtobe
# Processing Record 2 of Set 13 | guerrero negro
# Processing Record 3 of Set 13 | perry
# Processing Record 4 of Set 13 | port hardy
# Processing Record 5 of Set 13 | gumia
# Processing Record 6 of Set 13 | adrar
# Processing Record 7 of Set 13 | karpathos
# Processing Record 8 of Set 13 | loviisa
# Processing Record 9 of Set 13 | kibala
# Processing Record 10 of Set 13 | kosa
# Processing Record 11 of Set 13 | guozhen
# Processing Record 12 of Set 13 | corinto
# Processing Record 13 of Set 13 | pundaguitan
# Processing Record 14 of Set 13 | robertsport
# Processing Record 15 of Set 13 | abay
# Processing Record 16 of Set 13 | sola
# Processing Record 17 of Set 13 | petauke
# Processing Record 18 of Set 13 | boissevain
# Processing Record 19 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 20 of Set 13 | hingoli
# Processing Record 21 of Set 13 | kresttsy
# Processing Record 22 of Set 13 | mandera
# Processing Record 23 of Set 13 | brae
# Processing Record 24 of Set 13 | curumani
# Processing Record 25 of Set 13 | marsa matruh
# Processing Record 26 of Set 13 | pedinon
# Processing Record 27 of Set 13 | lodwar
# Processing Record 28 of Set 13 | barreirinha
# Processing Record 29 of Set 13 | tateyama
# Processing Record 30 of Set 13 | brewster
# Processing Record 31 of Set 13 | novaya mayna
# Processing Record 32 of Set 13 | koboldo
# City not found. Skipping...
# Processing Record 33 of Set 13 | burns lake
# Processing Record 34 of Set 13 | cockburn town
# Processing Record 35 of Set 13 | muzaffarabad
# Processing Record 36 of Set 13 | escanaba
# Processing Record 37 of Set 13 | haileybury
# Processing Record 38 of Set 13 | kundgol
# Processing Record 39 of Set 13 | velikie luki
# City not found. Skipping...
# Processing Record 40 of Set 13 | daliang
# Processing Record 41 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 42 of Set 13 | annapolis
# Processing Record 43 of Set 13 | bardiyah
# Processing Record 44 of Set 13 | invermere
# Processing Record 45 of Set 13 | mangoso
# Processing Record 46 of Set 13 | damavand
# Processing Record 47 of Set 13 | walvis bay
# Processing Record 48 of Set 13 | chulman
# Processing Record 49 of Set 13 | yaan
# Processing Record 50 of Set 13 | lasa
# Processing Record 1 of Set 14 | kieta
# Processing Record 2 of Set 14 | lagos
# Processing Record 3 of Set 14 | mahibadhoo
# Processing Record 4 of Set 14 | leh
# Processing Record 5 of Set 14 | saint-pierre
# Processing Record 6 of Set 14 | okhotsk
# Processing Record 7 of Set 14 | mount isa
# Processing Record 8 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 14 | port augusta
# Processing Record 10 of Set 14 | san lorenzo
# Processing Record 11 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 12 of Set 14 | ola
# Processing Record 13 of Set 14 | chaihe
# Processing Record 14 of Set 14 | santa cruz
# Processing Record 15 of Set 14 | komsomolskiy
# Processing Record 16 of Set 14 | kumbhraj
# Processing Record 17 of Set 14 | hun
# Processing Record 18 of Set 14 | tofield
# Processing Record 19 of Set 14 | koulikoro
# Processing Record 20 of Set 14 | toba
# Processing Record 21 of Set 14 | tineo
# Processing Record 22 of Set 14 | moscow
# Processing Record 23 of Set 14 | asosa
# Processing Record 24 of Set 14 | magadan
# Processing Record 25 of Set 14 | andenes
# Processing Record 26 of Set 14 | kajaani
# Processing Record 27 of Set 14 | geraldton
# Processing Record 28 of Set 14 | inhambane
# Processing Record 29 of Set 14 | tanabe
# Processing Record 30 of Set 14 | sao filipe
# Processing Record 31 of Set 14 | bayir
# Processing Record 32 of Set 14 | alekseyevka
# Processing Record 33 of Set 14 | birao
# Processing Record 34 of Set 14 | houston
# Processing Record 35 of Set 14 | nandi hills
# Processing Record 36 of Set 14 | inirida
# Processing Record 37 of Set 14 | pio xii
# Processing Record 38 of Set 14 | kleck
# City not found. Skipping...
# Processing Record 39 of Set 14 | udachnyy
# Processing Record 40 of Set 14 | havoysund
# Processing Record 41 of Set 14 | sussex
# Processing Record 42 of Set 14 | kerrobert
# Processing Record 43 of Set 14 | sita buzaului
# Processing Record 44 of Set 14 | santa maria
# Processing Record 45 of Set 14 | kloulklubed
# Processing Record 46 of Set 14 | porbandar
# Processing Record 47 of Set 14 | buin
# Processing Record 48 of Set 14 | bom jesus
# Processing Record 49 of Set 14 | copiapo
# Processing Record 50 of Set 14 | haradok
# Processing Record 1 of Set 15 | tam ky
# Processing Record 2 of Set 15 | lichtenburg
# Processing Record 3 of Set 15 | hervey bay
# Processing Record 4 of Set 15 | samarai
# Processing Record 5 of Set 15 | isla mujeres
# Processing Record 6 of Set 15 | sulphur
# Processing Record 7 of Set 15 | meulaboh
# Processing Record 8 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 9 of Set 15 | joshimath
# Processing Record 10 of Set 15 | pedro ii
# Processing Record 11 of Set 15 | anadyr
# Processing Record 12 of Set 15 | davila
# Processing Record 13 of Set 15 | calama
# Processing Record 14 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 15 | mabaruma
# Processing Record 16 of Set 15 | bubaque
# Processing Record 17 of Set 15 | constantine
# Processing Record 18 of Set 15 | sibolga
# Processing Record 19 of Set 15 | olinda
# Processing Record 20 of Set 15 | ust-kut
# Processing Record 21 of Set 15 | iracoubo
# Processing Record 22 of Set 15 | rolla
# Processing Record 23 of Set 15 | kashan
# Processing Record 24 of Set 15 | kandrian
# Processing Record 25 of Set 15 | neiafu
# Processing Record 26 of Set 15 | dourbali
# Processing Record 27 of Set 15 | bagamoyo
# Processing Record 28 of Set 15 | teberda
# Processing Record 29 of Set 15 | polyarnyy
# Processing Record 30 of Set 15 | campestre
# Processing Record 31 of Set 15 | bellavista
# Processing Record 32 of Set 15 | mrakovo
# Processing Record 33 of Set 15 | mana
# Processing Record 34 of Set 15 | grajau
# Processing Record 35 of Set 15 | pleasanton
# Processing Record 36 of Set 15 | riverton
# Processing Record 37 of Set 15 | jiblah
# Processing Record 38 of Set 15 | kharp
# Processing Record 39 of Set 15 | havre-saint-pierre
# Processing Record 40 of Set 15 | bilibino
# Processing Record 41 of Set 15 | sangar
# Processing Record 42 of Set 15 | pyapon
# Processing Record 43 of Set 15 | moyale
# Processing Record 44 of Set 15 | maldonado
# Processing Record 45 of Set 15 | baijiantan
# Processing Record 46 of Set 15 | nabire
# Processing Record 47 of Set 15 | yambio
# Processing Record 48 of Set 15 | puli
# Processing Record 49 of Set 15 | oktyabrskoye
# Processing Record 50 of Set 15 | linqu
# Processing Record 1 of Set 16 | gerash
# Processing Record 2 of Set 16 | portage
# Processing Record 3 of Set 16 | onega
# Processing Record 4 of Set 16 | luanda
# Processing Record 5 of Set 16 | aguimes
# Processing Record 6 of Set 16 | ballina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 695

# %%
# Convert the city_data to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas      CL -53.1500  -70.9167     39.31        81          40
# 1    Topolobampo      MX  25.6000 -109.0500     64.98        74          60
# 2    Alekseyevsk      RU  57.8406  108.3492     18.46        89         100
# 3           Lebu      CL -37.6167  -73.6500     52.54        78           0
# 4          Kapaa      US  22.0752 -159.3190     82.38        71          40
# 5       San Jose      US  37.3394 -121.8950     64.74        41          40
# 6        Ternate      ID   0.8000  127.4000     83.12        71          91
# 7         Bethel      US  41.3712  -73.4140     41.49        90          99
# 8       Tasiilaq      GL  65.6145  -37.6368     21.36        94         100
# 9  Alta Floresta      BR  -9.8756  -56.0861     71.69        96         100
#
#    Wind Speed Current Description
# 0       16.11    scattered clouds
# 1        4.85       broken clouds
# 2        6.55     overcast clouds
# 3       19.98           clear sky
# 4       19.57    scattered clouds
# 5       18.41    scattered clouds
# 6        3.33     overcast clouds
# 7        1.01     overcast clouds
# 8        8.25     overcast clouds
# 9        1.19     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
